# %% [markdown]
# <a href="https://colab.research.google.com/github/sdchen6/SSLM-Project/blob/main/chess_model_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install transformers
# !pip install python-chess

# %%
from datetime import datetime

from google.colab import drive
drive.mount('/content/gdrive')
folder = "/content/gdrive/MyDrive/Statistical_LM_Group_Folder"

csv_file = "chess_data_with_buckets.csv"
csv_path = f"{folder}/{csv_file}"


now = datetime.now()
dt_string = now.strftime("%m_%d_%Y_%H_%M")

model_file = "classifier_model.pth"
datetime = dt_string
model_path = f"{folder}/{datetime}_{model_file}"
# Out:
# Mounted at /content/gdrive

# %%
from transformers import BertTokenizer, AutoTokenizer, BertModel, BertConfig, get_linear_schedule_with_warmup
import torch.optim as optim
import torch
import torch.nn as nn
import torch.nn.functional as F
import pandas as pd
from tqdm import tqdm
import numpy as np
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader
from imblearn.under_sampling import RandomUnderSampler

# %% [markdown]
# ###Parameters

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

params = {
    "batch_size": 4,
    "epochs": 5,
    "learning_rate": 0.00003,
    "warmup_steps": 0.01,
    "epsilon": 1e-8,
    "accum_iter": 8,
    "num_classes": 6,
    "dropout": 0.5
}

class Params:
  def __init__(self, **kwargs):
    for key, value in kwargs.items():
      setattr(self, key, value)

params = Params(**params)

# %% [markdown]
# ### Classify Model

# %%
class BertClassifier(nn.Module):
  def __init__(self, dropout=params.dropout, num_classes=params.num_classes):
    super(BertClassifier, self).__init__()

    self.bert = BertModel.from_pretrained('bert-base-cased')
    self.dropout = nn.Dropout(dropout)
    self.linear = nn.Linear(768, num_classes)
    # self.relu = nn.ReLU()
    self.softmax = nn.LogSoftmax(dim=1)

  def forward(self, input_id, mask):
    _, pooled_output = self.bert(input_ids= input_id, attention_mask=mask,return_dict=False)
    dropout_output = self.dropout(pooled_output)
    linear_output = self.linear(dropout_output)
    final_layer = self.softmax(linear_output)

    return final_layer

# %% [markdown]
# ### Dataset Class

# %%
class ChessDataset(torch.utils.data.Dataset):
  def __init__(self, moves, labels):
      tokenizer = BertTokenizer.from_pretrained('bert-base-cased')
      self.labels = torch.Tensor(labels.values)
      self.moves = [tokenizer(move, 
                              padding='max_length', max_length = 256, truncation=True,
                              return_tensors="pt") for move in moves]

  def __len__(self):
      return len(self.labels)

  def __getitem__(self, idx):
      return self.moves[idx], self.labels[idx]

# %% [markdown]
# ### Training Function

# %%
def train(model, train_dataloader, val_dataloader, criterion, optimizer):
    num_batches = len(train_dataloader)
    scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps = params.warmup_steps, num_training_steps = num_batches * params.epochs)
    print(f"Number of batches: {num_batches}")
    for epoch_num in range(params.epochs):
        total_acc_train = 0
        total_loss_train = 0

        for batch_idx, (train_input, train_label) in enumerate(train_dataloader):
        #   print(sum(train_input['input_ids'].squeeze(1)[0] == 0))
          train_label = train_label.to(device)
          mask = train_input['attention_mask'].to(device)
          input_id = train_input['input_ids'].squeeze(1).to(device)

          output = model(input_id, mask)
          
          batch_loss = criterion(output, train_label.long())
          total_loss_train += batch_loss.item()
          
          acc = (output.argmax(dim=1) == train_label).sum().item()
          total_acc_train += acc

          batch_loss.backward()

          # Gradient Accumulation
          if ((batch_idx + 1) % params.accum_iter == 0) or (batch_idx + 1 == num_batches):
            optimizer.step()
            scheduler.step()
            optimizer.zero_grad()

          if batch_idx % 50 == 0:
            print(f"Batch Number: {batch_idx}")
            print(f"Model Output: {torch.exp(output).tolist()}")
        
        total_acc_val = 0
        total_loss_val = 0

        with torch.no_grad():

          for val_input, val_label in val_dataloader:
            val_label = val_label.to(device)
            mask = val_input['attention_mask'].to(device)
            input_id = val_input['input_ids'].squeeze(1).to(device)

            output = model(input_id, mask)
            
            batch_loss = criterion(output, val_label.long())
            total_loss_val += batch_loss.item()
            
            acc = (output.argmax(dim=1) == val_label).sum().item()
            total_acc_val += acc
        
        print(
            f'Epochs: {epoch_num + 1} | Train Loss: {total_loss_train / len(train_dataloader): .3f} \
            | Train Accuracy: {total_acc_train / len(train_dataloader): .3f} \
            | Val Loss: {total_loss_val / len(val_dataloader): .3f} \
            | Val Accuracy: {total_acc_val / len(val_dataloader): .3f}')
        
        torch.save(model.state_dict(), model_path)

# %% [markdown]
# ### Test Function

# %%
def test(model, test_dataloader):
  total_acc_test = 0
  with torch.no_grad():
    for test_input, test_label in test_dataloader:
      test_label = test_label.to(device)
      mask = test_input['attention_mask'].to(device)
      input_id = test_input['input_ids'].squeeze(1).to(device)

      output = model(input_id, mask)
      print(f"Model Output: {torch.exp(output).tolist()}")
      print(f"Prediction: {output.argmax(dim=1).tolist()}, Truth: {test_label.tolist()}")

      acc = (output.argmax(dim=1) == test_label).sum().item()
      total_acc_test += acc
       
      print(f"Test Accuracy: {total_acc_test / len(test_dataloader): .3f}")

# %% [markdown]
# ### Loading Data

# %%
# %%capture
chess_data = pd.read_csv(csv_path)[0:3000]
X = chess_data["Moves"]
y = chess_data["Bucket"]

balancer = RandomUnderSampler()
X = X.values.reshape(-1, 1)
X, y = balancer.fit_resample(X, y)
rating_counts = y.value_counts().sort_index()
X = X.flatten()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=7, shuffle=True) # Splits into train/test
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=1, shuffle=True) # Splits train into train/val

train_data, val_data, test_data = ChessDataset(X_train, y_train), ChessDataset(X_val, y_val), ChessDataset(X_test, y_test)

# %%
train_dataloader = torch.utils.data.DataLoader(train_data, batch_size=params.batch_size, shuffle=True)
val_dataloader = torch.utils.data.DataLoader(val_data, batch_size=params.batch_size)
test_dataloader = torch.utils.data.DataLoader(test_data)

# %% [markdown]
# ### Initialize Model

# %%
# %%capture
model = BertClassifier()
model = model.to(device)
criterion = nn.NLLLoss()
optimizer = optim.AdamW(model.parameters(), lr = params.learning_rate)
# Out:
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertModel: ['cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# ### Run Training

# %%
train(model, train_dataloader, val_dataloader, criterion, optimizer)
# Out:
# Number of batches: 175
# Batch Number: 0
# Model Output: [[-2.1017754077911377, -2.5098466873168945, -2.672037124633789, -2.0587315559387207, -0.8309098482131958, -1.8072774410247803], [-1.659617304801941, -3.537363052368164, -3.015733242034912, -1.1911700963974, -2.2322874069213867, -1.137747883796692], [-1.4947092533111572, -2.511418342590332, -2.658843517303467, -1.6807351112365723, -1.2118192911148071, -1.9617536067962646], [-1.9843368530273438, -2.668450117111206, -2.550992727279663, -0.8165637850761414, -1.7257781028747559, -2.3519623279571533]]
# Batch Number: 50
# Model Output: [[-1.941298484802246, -1.9894174337387085, -2.0516977310180664, -1.2319469451904297, -1.8383702039718628, -1.9633283615112305], [-1.9159021377563477, -1.7567603588104248, -1.3830958604812622, -1.740067958831787, -1.9456660747528076, -2.1983461380004883], [-2.105015754699707, -1.6942380666732788, -1.4462732076644897, -1.6935241222381592, -1.6980078220367432, -2.3853936195373535], [-2.1473894119262695, -1.8172169923782349, -2.193108558654785, -1.8209503889083862, -1.1592367887496948, -2.0131497383117676]]
# Batch Number: 100
# Model Output: [[-1.9318952560424805, -1.9470933675765991, -1.5412635803222656, -2.122281789779663, -1.538206696510315, -1.8090839385986328], [-1.800189733505249, -1.2977102994918823, -2.0616962909698486, -1.6488628387451172, -2.023629903793335, -2.208232879638672], [-1.8377454280853271, -1.690102458000183, -2.0057790279388428, -1.3577079772949219, -1.971620798110962, -2.077145576477051], [-2.1609864234924316, -1.4098376035690308, -1.5223512649536133, -1.7421876192092896, -2.1988577842712402, -1.9925975799560547]]
# Batch Number: 150
# Model Output: [[-2.039781332015991, -1.4342387914657593, -1.7720768451690674, -1.6834241151809692, -1.834134578704834, -2.152632236480713], [-1.475828766822815, -2.094409942626953, -1.5261718034744263, -2.4057693481445312, -1.393239140510559, -2.381239652633667], [-1.4480916261672974, -2.429030656814575, -2.029569387435913, -2.1434366703033447, -1.4557361602783203, -1.634819746017456], [-1.9734861850738525, -2.002847194671631, -1.98434579372406, -1.8926550149917603, -1.517322301864624, -1.5203386545181274]]
# Epochs: 1 | Train Loss:  1.871             | Train Accuracy:  0.766             | Val Loss:  1.807             | Val Accuracy:  0.763
# Batch Number: 0
# Model Output: [[-1.6988800764083862, -1.9081284999847412, -1.662919521331787, -1.9390835762023926, -1.774855375289917, -1.7968182563781738], [-2.0398221015930176, -2.40407133102417, -1.361527681350708, -2.645756244659424, -1.354084849357605, -1.6388938426971436], [-1.4434359073638916, -2.229999542236328, -2.1304025650024414, -1.6849735975265503, -1.6258368492126465, -1.8619418144226074], [-2.5081496238708496, -1.3235377073287964, -2.0150809288024902, -1.9382688999176025, -1.340786337852478, -2.176067352294922]]
# Batch Number: 50
# Model Output: [[-1.9482406377792358, -1.5375615358352661, -1.9550076723098755, -1.6710718870162964, -1.9133317470550537, -1.799543857574463], [-2.209907054901123, -1.6810775995254517, -2.167269468307495, -1.3947248458862305, -1.8812330961227417, -1.6643016338348389], [-1.617188572883606, -1.4579089879989624, -2.581188440322876, -2.0291574001312256, -2.059018850326538, -1.451953411102295], [-2.023636817932129, -1.4462051391601562, -1.6420550346374512, -1.861743450164795, -2.1164424419403076, -1.8144879341125488]]
# Batch Number: 100
# Model Output: [[-1.9969391822814941, -1.485255241394043, -2.2183640003204346, -1.9771056175231934, -1.8222873210906982, -1.474498987197876], [-1.9629480838775635, -1.6011617183685303, -2.123476028442383, -1.9649126529693604, -1.4669758081436157, -1.7868375778198242], [-1.8055005073547363, -1.7588951587677002, -1.4790971279144287, -2.0057852268218994, -2.1247782707214355, -1.7064144611358643], [-2.22776460647583, -1.6707353591918945, -1.4326541423797607, -2.1562886238098145, -1.706355333328247, -1.7827949523925781]]
# Batch Number: 150
# Model Output: [[-1.817828893661499, -1.617408037185669, -2.0370802879333496, -1.6071525812149048, -1.936649203300476, -1.806931972503662], [-1.409735083580017, -2.031468152999878, -2.325871467590332, -1.5388550758361816, -2.10355806350708, -1.6591390371322632], [-1.861286997795105, -1.891556978225708, -1.9390302896499634, -1.5739799737930298, -2.337066173553467, -1.4023507833480835], [-1.3816077709197998, -2.08870530128479, -1.971947431564331, -1.5515222549438477, -1.8390007019042969, -2.163769006729126]]
# Epochs: 2 | Train Loss:  1.822             | Train Accuracy:  0.697             | Val Loss:  1.839             | Val Accuracy:  0.661
# Batch Number: 0
# Model Output: [[-1.3390790224075317, -1.6680669784545898, -1.979283332824707, -1.819948434829712, -2.0850067138671875, -2.0810983180999756], [-1.6295099258422852, -1.8148248195648193, -1.6671162843704224, -1.6098805665969849, -1.8705610036849976, -2.319033622741699], [-1.0855399370193481, -1.60538649559021, -2.31357741355896, -2.0407543182373047, -2.1904959678649902, -2.11386775970459], [-1.9173471927642822, -1.804076910018921, -2.0176522731781006, -1.738396406173706, -1.6728802919387817, -1.6507692337036133]]
# Batch Number: 50
# Model Output: [[-2.0715525150299072, -1.75602126121521, -1.416345238685608, -1.8670611381530762, -1.9126577377319336, -1.8552390336990356], [-1.769973635673523, -1.8449187278747559, -1.707829236984253, -1.733259677886963, -1.5909008979797363, -2.208037853240967], [-1.8886116743087769, -1.988256812095642, -1.5466678142547607, -1.7356460094451904, -1.6066993474960327, -2.1037895679473877], [-2.254472255706787, -2.0261056423187256, -1.8666495084762573, -1.6232810020446777, -1.4791637659072876, -1.6955211162567139]]
# Batch Number: 100
# Model Output: [[-1.991698980331421, -1.3607221841812134, -1.7675853967666626, -1.8652909994125366, -1.975205659866333, -1.946783423423767], [-2.011366844177246, -1.2762298583984375, -1.8072009086608887, -2.07968807220459, -1.8527748584747314, -1.9574123620986938], [-1.8569241762161255, -1.637356162071228, -1.5541223287582397, -1.5273500680923462, -2.16536283493042, -2.242800235748291], [-1.8496540784835815, -1.5907543897628784, -1.8415961265563965, -2.0444297790527344, -1.6902985572814941, -1.7930359840393066]]
# Batch Number: 150
# Model Output: [[-2.186903715133667, -1.6470680236816406, -1.3311092853546143, -1.873280644416809, -2.1295788288116455, -1.8424289226531982], [-2.1205391883850098, -1.6631357669830322, -1.7874897718429565, -1.6195335388183594, -1.6823742389678955, -1.971940040588379], [-1.9598826169967651, -1.610041856765747, -2.0178351402282715, -1.6991416215896606, -1.91860032081604, -1.6263293027877808], [-2.19073748588562, -1.5225790739059448, -1.6885961294174194, -1.456562876701355, -2.259974956512451, -1.9115604162216187]]
# Epochs: 3 | Train Loss:  1.811             | Train Accuracy:  0.629             | Val Loss:  1.810             | Val Accuracy:  0.644
# Batch Number: 0
# Model Output: [[-1.6279319524765015, -1.9646409749984741, -2.1777243614196777, -1.5380641222000122, -1.8640131950378418, -1.7130565643310547], [-1.861183524131775, -1.6733818054199219, -1.7590054273605347, -1.7319183349609375, -2.2464308738708496, -1.5996699333190918], [-1.8118994235992432, -1.7578620910644531, -1.8712446689605713, -1.4589407444000244, -2.153555154800415, -1.8216526508331299], [-1.760737419128418, -1.558080792427063, -1.794859766960144, -1.8399860858917236, -2.431914806365967, -1.586193323135376]]
# Batch Number: 50
# Model Output: [[-1.6862483024597168, -1.7997902631759644, -2.0195019245147705, -1.9927592277526855, -1.7197223901748657, -1.602973222732544], [-1.7359075546264648, -1.5283359289169312, -2.088064670562744, -2.023393392562866, -1.7068499326705933, -1.7761168479919434], [-1.8896307945251465, -1.8034698963165283, -2.077298402786255, -1.9486031532287598, -1.5157963037490845, -1.6257109642028809], [-1.6640526056289673, -1.9415397644042969, -2.005218982696533, -2.1494956016540527, -1.6337378025054932, -1.5106112957000732]]
# Batch Number: 100
# Model Output: [[-1.7044422626495361, -1.6364657878875732, -1.8907618522644043, -2.0578103065490723, -1.6375820636749268, -1.8949919939041138], [-2.1402792930603027, -2.0328383445739746, -1.7585662603378296, -1.6266965866088867, -1.8216382265090942, -1.5105679035186768], [-2.140644073486328, -2.1013429164886475, -1.4610822200775146, -1.8337719440460205, -1.7899140119552612, -1.6026628017425537], [-1.739601492881775, -2.09226131439209, -1.9784318208694458, -1.8424835205078125, -1.7997263669967651, -1.4315080642700195]]
# Batch Number: 150
# Model Output: [[-2.2310776710510254, -1.6359833478927612, -2.154557466506958, -1.6558001041412354, -1.6071486473083496, -1.6582366228103638], [-2.2042622566223145, -1.79279363155365, -1.5496776103973389, -1.6596566438674927, -1.8738787174224854, -1.7890077829360962], [-2.5186033248901367, -1.7374324798583984, -1.9566340446472168, -1.7626097202301025, -1.4515323638916016, -1.6280325651168823], [-2.439359664916992, -1.62661612033844, -2.0247669219970703, -1.9195464849472046, -1.3924003839492798, -1.6659376621246338]]
# Epochs: 4 | Train Loss:  1.802             | Train Accuracy:  0.726             | Val Loss:  1.835             | Val Accuracy:  0.627
# Batch Number: 0
# Model Output: [[-2.4756178855895996, -1.661772608757019, -1.4597561359405518, -1.7827870845794678, -1.8304798603057861, -1.8000638484954834], [-2.1119606494903564, -2.1451704502105713, -1.5306754112243652, -1.8902006149291992, -1.5048871040344238, -1.7574849128723145], [-2.7404568195343018, -2.04849910736084, -1.8720359802246094, -1.8908653259277344, -1.8170125484466553, -1.08096182346344], [-2.3079404830932617, -1.6131335496902466, -1.661736011505127, -1.9453613758087158, -1.9153286218643188, -1.508535623550415]]
# Batch Number: 50
# Model Output: [[-1.902212142944336, -1.7643423080444336, -2.0528581142425537, -1.7667754888534546, -1.6388753652572632, -1.681936264038086], [-1.9841277599334717, -1.5176331996917725, -1.5878771543502808, -2.2293529510498047, -1.7557733058929443, -1.8417562246322632], [-1.4856008291244507, -1.3603770732879639, -2.004041910171509, -2.106971263885498, -2.0075430870056152, -2.0686497688293457], [-1.8807182312011719, -1.7497718334197998, -1.899832010269165, -2.0134358406066895, -1.650189757347107, -1.6166163682937622]]
# Batch Number: 100
# Model Output: [[-1.2546257972717285, -2.0169568061828613, -2.0301549434661865, -1.8642102479934692, -1.7704637050628662, -2.0780842304229736], [-1.7023786306381226, -1.9561915397644043, -2.057222843170166, -1.6518298387527466, -1.6467058658599854, -1.806890845298767], [-1.4400650262832642, -1.7084828615188599, -1.9668693542480469, -1.8395131826400757, -2.137676954269409, -1.800417423248291], [-2.0677261352539062, -2.2430760860443115, -2.2442901134490967, -1.4682661294937134, -1.4009596109390259, -1.6889809370040894]]
# Batch Number: 150
# Model Output: [[-2.0868868827819824, -1.627302646636963, -1.7548236846923828, -1.7307672500610352, -1.5716986656188965, -2.1062769889831543], [-1.760425090789795, -1.6737529039382935, -1.4772095680236816, -1.9861862659454346, -1.940619945526123, -2.0296623706817627], [-1.936121940612793, -1.3998286724090576, -1.7306267023086548, -1.8969340324401855, -1.8054808378219604, -2.141301155090332], [-2.1007399559020996, -1.7123990058898926, -1.513526439666748, -1.854294776916504, -1.5722957849502563, -2.1809167861938477]]
# Epochs: 5 | Train Loss:  1.784             | Train Accuracy:  0.709             | Val Loss:  1.749             | Val Accuracy:  0.831

# %% [markdown]
# ### Run Testing

# %%
test_model_name = "06_01_2023_20_16_classifier_model.pth"
test_model_path = f"{folder}/{test_model_name}"

test_model = BertClassifier()
test_model = test_model.to(device)
test_model.load_state_dict(torch.load(test_model_path))
test(test_model, test_dataloader)
# Out:
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertModel: ['cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Model Output: [[0.0055365245789289474, 0.015902314335107803, 0.04718215391039848, 0.1230897456407547, 0.2625628113746643, 0.545726478099823]]
# Prediction: [5], Truth: [4.0]
# Test Accuracy:  0.000
# Model Output: [[0.00308427307754755, 0.012025650590658188, 0.20738238096237183, 0.48318400979042053, 0.23894932866096497, 0.05537435784935951]]
# Prediction: [3], Truth: [2.0]
# Test Accuracy:  0.000
# Model Output: [[0.009098488837480545, 0.03602316230535507, 0.15622936189174652, 0.38835570216178894, 0.29521700739860535, 0.11507640779018402]]
# Prediction: [3], Truth: [2.0]
# Test Accuracy:  0.000
# Model Output: [[0.004297912120819092, 0.01824401505291462, 0.12401041388511658, 0.4060603082180023, 0.2988314628601074, 0.14855578541755676]]
# Prediction: [3], Truth: [4.0]
# Test Accuracy:  0.000
# Model Output: [[0.007114664651453495, 0.03649771586060524, 0.17367158830165863, 0.38893264532089233, 0.28563982248306274, 0.10814351588487625]]
# Prediction: [3], Truth: [4.0]
# Test Accuracy:  0.000
# Model Output: [[0.5700535178184509, 0.3693241775035858, 0.04450413957238197, 0.010546564124524593, 0.0021214988082647324, 0.0034500588662922382]]
# Prediction: [0], Truth: [0.0]
# Test Accuracy:  0.004
# Model Output: [[0.011800439096987247, 0.05811537802219391, 0.20476266741752625, 0.6192222237586975, 0.09060217440128326, 0.015497137792408466]]
# Prediction: [3], Truth: [2.0]
# Test Accuracy:  0.004
# Model Output: [[0.0013385938946157694, 0.00807974673807621, 0.09119335561990738, 0.3935326635837555, 0.3173147439956665, 0.18854090571403503]]
# Prediction: [3], Truth: [4.0]
# Test Accuracy:  0.004
# Model Output: [[0.11133618652820587, 0.3000090718269348, 0.40789228677749634, 0.14772285521030426, 0.0257281307131052, 0.007311461493372917]]
# Prediction: [2], Truth: [2.0]
# Test Accuracy:  0.009
# Model Output: [[0.002800682792440057, 0.005331306252628565, 0.025390392169356346, 0.09249096363782883, 0.36332377791404724, 0.5106629729270935]]
# Prediction: [5], Truth: [5.0]
# Test Accuracy:  0.013
# Model Output: [[0.003467713249847293, 0.017283722758293152, 0.10866901278495789, 0.2855722904205322, 0.3811713457107544, 0.2038358449935913]]
# Prediction: [4], Truth: [2.0]
# Test Accuracy:  0.013
# Model Output: [[0.0016810877714306116, 0.0021056728437542915, 0.008832171559333801, 0.03168501332402229, 0.16786442697048187, 0.7878316044807434]]
# Prediction: [5], Truth: [5.0]
# Test Accuracy:  0.017
# Model Output: [[0.144891157746315, 0.5550218820571899, 0.2663722634315491, 0.028676385059952736, 0.0040603987872600555, 0.000977846677415073]]
# Prediction: [1], Truth: [2.0]
# Test Accuracy:  0.017
# Model Output: [[0.8502314686775208, 0.12836773693561554, 0.01762443780899048, 0.0016521768411621451, 0.0006467315251938999, 0.0014774580486118793]]
# Prediction: [0], Truth: [0.0]
# Test Accuracy:  0.021
# Model Output: [[0.6417598724365234, 0.3115222454071045, 0.04040181264281273, 0.00366219156421721, 0.0015354908537119627, 0.001118386397138238]]
# Prediction: [0], Truth: [0.0]
# Test Accuracy:  0.026
# Model Output: [[0.7804083228111267, 0.19030466675758362, 0.022019462659955025, 0.004403290804475546, 0.001418114872649312, 0.0014461218379437923]]
# Prediction: [0], Truth: [2.0]
# Test Accuracy:  0.026
# Model Output: [[0.19793786108493805, 0.3577500283718109, 0.242674320936203, 0.1151588186621666, 0.05087752640247345, 0.03560145944356918]]
# Prediction: [1], Truth: [2.0]
# Test Accuracy:  0.026
# Model Output: [[0.11163287609815598, 0.28702351450920105, 0.3621530830860138, 0.18508903682231903, 0.042254865169525146, 0.011846669018268585]]
# Prediction: [2], Truth: [2.0]
# Test Accuracy:  0.030
# Model Output: [[0.030733680352568626, 0.12170227617025375, 0.2788046896457672, 0.2951757609844208, 0.16819123923778534, 0.10539238899946213]]
# Prediction: [3], Truth: [3.0]
# Test Accuracy:  0.034
# Model Output: [[0.578625500202179, 0.36158648133277893, 0.046065498143434525, 0.010131905786693096, 0.0015055583789944649, 0.0020851697772741318]]
# Prediction: [0], Truth: [0.0]
# Test Accuracy:  0.039
# Model Output: [[0.23546236753463745, 0.35671359300613403, 0.21963293850421906, 0.12162543088197708, 0.04253707826137543, 0.024028649553656578]]
# Prediction: [1], Truth: [4.0]
# Test Accuracy:  0.039
# Model Output: [[0.003052503103390336, 0.010616622865200043, 0.04831754043698311, 0.1982206553220749, 0.44322651624679565, 0.2965662181377411]]
# Prediction: [4], Truth: [4.0]
# Test Accuracy:  0.043
# Model Output: [[0.11705536395311356, 0.3479447066783905, 0.37486347556114197, 0.11472193151712418, 0.034004099667072296, 0.011410451494157314]]
# Prediction: [2], Truth: [2.0]
# Test Accuracy:  0.047
# Model Output: [[0.1290774643421173, 0.6161958575248718, 0.20275352895259857, 0.03785556182265282, 0.008210194297134876, 0.005907400976866484]]
# Prediction: [1], Truth: [1.0]
# Test Accuracy:  0.052
# Model Output: [[0.6428274512290955, 0.30064260959625244, 0.04781213030219078, 0.006795062683522701, 0.0013437361922115088, 0.000578973616939038]]
# Prediction: [0], Truth: [0.0]
# Test Accuracy:  0.056
# Model Output: [[0.0010377693688496947, 0.005569249391555786, 0.0404416061937809, 0.2989630699157715, 0.37709128856658936, 0.27689698338508606]]
# Prediction: [4], Truth: [3.0]
# Test Accuracy:  0.056
# Model Output: [[0.003310510655865073, 0.02351933717727661, 0.1069893091917038, 0.3974149227142334, 0.33699774742126465, 0.13176807761192322]]
# Prediction: [3], Truth: [0.0]
# Test Accuracy:  0.056
# Model Output: [[0.0024418532848358154, 0.007751129101961851, 0.034909892827272415, 0.12725624442100525, 0.4817911982536316, 0.34584975242614746]]
# Prediction: [4], Truth: [2.0]
# Test Accuracy:  0.056
# Model Output: [[0.004996670410037041, 0.02036849968135357, 0.0908009484410286, 0.2564123570919037, 0.46483802795410156, 0.16258350014686584]]
# Prediction: [4], Truth: [3.0]
# Test Accuracy:  0.056
# Model Output: [[0.24734239280223846, 0.44509023427963257, 0.21243196725845337, 0.053164783865213394, 0.028289401903748512, 0.013681276701390743]]
# Prediction: [1], Truth: [1.0]
# Test Accuracy:  0.060
# Model Output: [[0.603571355342865, 0.3586638569831848, 0.03112117573618889, 0.002730895299464464, 0.0019632100593298674, 0.001949526951648295]]
# Prediction: [0], Truth: [2.0]
# Test Accuracy:  0.060
# Model Output: [[0.01701226644217968, 0.10580027103424072, 0.21034595370292664, 0.3600020706653595, 0.2006160467863083, 0.10622334480285645]]
# Prediction: [3], Truth: [0.0]
# Test Accuracy:  0.060
# Model Output: [[0.4706641733646393, 0.43027275800704956, 0.06674664467573166, 0.01691148243844509, 0.006661419756710529, 0.008743475191295147]]
# Prediction: [0], Truth: [5.0]
# Test Accuracy:  0.060
# Model Output: [[0.228951096534729, 0.318023681640625, 0.24386052787303925, 0.14309997856616974, 0.039356689900159836, 0.026707857847213745]]
# Prediction: [1], Truth: [3.0]
# Test Accuracy:  0.060
# Model Output: [[0.0006831419887021184, 0.002354878466576338, 0.011936533264815807, 0.04361896589398384, 0.30862170457839966, 0.6327847242355347]]
# Prediction: [5], Truth: [5.0]
# Test Accuracy:  0.064
# Model Output: [[0.0010446351952850819, 0.001963413320481777, 0.00742505956441164, 0.03790769726037979, 0.1483922153711319, 0.8032670021057129]]
# Prediction: [5], Truth: [5.0]
# Test Accuracy:  0.069
# Model Output: [[0.07550893723964691, 0.19051527976989746, 0.32015857100486755, 0.2262742668390274, 0.13396085798740387, 0.05358204245567322]]
# Prediction: [2], Truth: [0.0]
# Test Accuracy:  0.069
# Model Output: [[0.002056271070614457, 0.011709305457770824, 0.08572719246149063, 0.3493092358112335, 0.3980984389781952, 0.15309961140155792]]
# Prediction: [4], Truth: [4.0]
# Test Accuracy:  0.073
# Model Output: [[0.0011725552612915635, 0.0030618838500231504, 0.010182378813624382, 0.07176274061203003, 0.339374840259552, 0.5744456052780151]]
# Prediction: [5], Truth: [4.0]
# Test Accuracy:  0.073
# Model Output: [[0.00042752298759296536, 0.0016760212602093816, 0.009457900188863277, 0.04970907047390938, 0.42844054102897644, 0.5102889537811279]]
# Prediction: [5], Truth: [2.0]
# Test Accuracy:  0.073
# Model Output: [[0.058349356055259705, 0.17658640444278717, 0.35477718710899353, 0.2900972068309784, 0.08750035613775253, 0.03268955647945404]]
# Prediction: [2], Truth: [0.0]
# Test Accuracy:  0.073
# Model Output: [[0.394961416721344, 0.48979097604751587, 0.09396151453256607, 0.014550461433827877, 0.005113192368298769, 0.0016224582213908434]]
# Prediction: [1], Truth: [1.0]
# Test Accuracy:  0.077
# Model Output: [[0.04924936592578888, 0.17336426675319672, 0.2589734196662903, 0.3727077841758728, 0.11022674292325974, 0.03547843545675278]]
# Prediction: [3], Truth: [1.0]
# Test Accuracy:  0.077
# Model Output: [[0.01967724598944187, 0.08650722354650497, 0.29190710186958313, 0.3386812210083008, 0.1851966828107834, 0.07803043723106384]]
# Prediction: [3], Truth: [3.0]
# Test Accuracy:  0.082
# Model Output: [[0.1512984037399292, 0.5915284752845764, 0.22088217735290527, 0.029461897909641266, 0.005570426117628813, 0.0012586162192746997]]
# Prediction: [1], Truth: [1.0]
# Test Accuracy:  0.086
# Model Output: [[0.006279690656810999, 0.038389552384614944, 0.3175610601902008, 0.5124977827072144, 0.10937271267175674, 0.01589922048151493]]
# Prediction: [3], Truth: [2.0]
# Test Accuracy:  0.086
# Model Output: [[0.007527171168476343, 0.030079612508416176, 0.16979151964187622, 0.5511525869369507, 0.20610001683235168, 0.035349041223526]]
# Prediction: [3], Truth: [1.0]
# Test Accuracy:  0.086
# Model Output: [[0.0006111740367487073, 0.0017974207876250148, 0.012664122506976128, 0.07311252504587173, 0.3315387964248657, 0.5802759528160095]]
# Prediction: [5], Truth: [2.0]
# Test Accuracy:  0.086
# Model Output: [[0.3223806321620941, 0.3910849094390869, 0.21504107117652893, 0.05688101798295975, 0.010453876107931137, 0.004158526659011841]]
# Prediction: [1], Truth: [1.0]
# Test Accuracy:  0.090
# Model Output: [[0.8239432573318481, 0.15187372267246246, 0.01765548251569271, 0.0037592703010886908, 0.0014710406539961696, 0.001297274138778448]]
# Prediction: [0], Truth: [2.0]
# Test Accuracy:  0.090
# Model Output: [[0.0018505663610994816, 0.007962501607835293, 0.03496537730097771, 0.14546947181224823, 0.3871505856513977, 0.42260149121284485]]
# Prediction: [5], Truth: [5.0]
# Test Accuracy:  0.094
# Model Output: [[0.006598397623747587, 0.04778618365526199, 0.25710368156433105, 0.45807987451553345, 0.19353844225406647, 0.03689348325133324]]
# Prediction: [3], Truth: [2.0]
# Test Accuracy:  0.094
# Model Output: [[0.29665493965148926, 0.23503224551677704, 0.11613696068525314, 0.1105310395359993, 0.07225798815488815, 0.1693868637084961]]
# Prediction: [0], Truth: [0.0]
# Test Accuracy:  0.099
# Model Output: [[0.0032206468749791384, 0.02669147215783596, 0.17606815695762634, 0.5271983742713928, 0.22655297815799713, 0.04026844725012779]]
# Prediction: [3], Truth: [3.0]
# Test Accuracy:  0.103
# Model Output: [[0.5955931544303894, 0.38673120737075806, 0.014117195270955563, 0.002398598240688443, 0.0006224309327080846, 0.0005373960011638701]]
# Prediction: [0], Truth: [1.0]
# Test Accuracy:  0.103
# Model Output: [[0.0011401508236303926, 0.0062908572144806385, 0.04004916176199913, 0.4017544686794281, 0.3616878390312195, 0.1890774965286255]]
# Prediction: [3], Truth: [4.0]
# Test Accuracy:  0.103
# Model Output: [[0.0011791113065555692, 0.009123217314481735, 0.05584593862295151, 0.3636226952075958, 0.3820632994174957, 0.18816573917865753]]
# Prediction: [4], Truth: [4.0]
# Test Accuracy:  0.107
# Model Output: [[0.005299646407365799, 0.02003510668873787, 0.11814562231302261, 0.34922271966934204, 0.36647307872772217, 0.1408238708972931]]
# Prediction: [4], Truth: [3.0]
# Test Accuracy:  0.107
# Model Output: [[0.000534888356924057, 0.00479760579764843, 0.1134256049990654, 0.7826541662216187, 0.08243045955896378, 0.016157174482941628]]
# Prediction: [3], Truth: [3.0]
# Test Accuracy:  0.112
# Model Output: [[0.14883878827095032, 0.5303178429603577, 0.2734810709953308, 0.039337486028671265, 0.006596912629902363, 0.0014279281022027135]]
# Prediction: [1], Truth: [2.0]
# Test Accuracy:  0.112
# Model Output: [[0.41561415791511536, 0.4567633271217346, 0.10905954241752625, 0.014665897004306316, 0.0025019270833581686, 0.0013952207518741488]]
# Prediction: [1], Truth: [2.0]
# Test Accuracy:  0.112
# Model Output: [[0.004853609949350357, 0.023493604734539986, 0.14963731169700623, 0.33543774485588074, 0.28556719422340393, 0.20101049542427063]]
# Prediction: [3], Truth: [3.0]
# Test Accuracy:  0.116
# Model Output: [[0.624453604221344, 0.3298998475074768, 0.03356480970978737, 0.005964564625173807, 0.002624343615025282, 0.0034928666427731514]]
# Prediction: [0], Truth: [0.0]
# Test Accuracy:  0.120
# Model Output: [[0.11925984919071198, 0.4120192229747772, 0.33856841921806335, 0.0927027240395546, 0.026818258687853813, 0.010631450451910496]]
# Prediction: [1], Truth: [1.0]
# Test Accuracy:  0.124
# Model Output: [[0.7995918989181519, 0.18019825220108032, 0.017993340268731117, 0.0013385402271524072, 0.0004194538632873446, 0.0004585311689879745]]
# Prediction: [0], Truth: [0.0]
# Test Accuracy:  0.129
# Model Output: [[0.4510841965675354, 0.4542770981788635, 0.05857831612229347, 0.024882052093744278, 0.007313232868909836, 0.0038651837967336178]]
# Prediction: [1], Truth: [1.0]
# Test Accuracy:  0.133
# Model Output: [[0.0054345931857824326, 0.02863764576613903, 0.21580637991428375, 0.3550896942615509, 0.29798293113708496, 0.09704873710870743]]
# Prediction: [3], Truth: [3.0]
# Test Accuracy:  0.137
# Model Output: [[0.002202459145337343, 0.006209230050444603, 0.05154820904135704, 0.3373538553714752, 0.3825562000274658, 0.22013002634048462]]
# Prediction: [4], Truth: [3.0]
# Test Accuracy:  0.137
# Model Output: [[0.02069050446152687, 0.07095251977443695, 0.18089668452739716, 0.20136168599128723, 0.23675161600112915, 0.28934693336486816]]
# Prediction: [5], Truth: [4.0]
# Test Accuracy:  0.137
# Model Output: [[0.07305401563644409, 0.3181837201118469, 0.3169155418872833, 0.2530026137828827, 0.02874099463224411, 0.010103119537234306]]
# Prediction: [1], Truth: [2.0]
# Test Accuracy:  0.137
# Model Output: [[0.19282859563827515, 0.3700380325317383, 0.2659820318222046, 0.0952291414141655, 0.0490189753472805, 0.026903163641691208]]
# Prediction: [1], Truth: [4.0]
# Test Accuracy:  0.137
# Model Output: [[0.7981863021850586, 0.18268431723117828, 0.014535794965922832, 0.002898583887144923, 0.0007534374599345028, 0.0009416154935024679]]
# Prediction: [0], Truth: [0.0]
# Test Accuracy:  0.142
# Model Output: [[0.7684583067893982, 0.19766797125339508, 0.02366291731595993, 0.006503832060843706, 0.0015827006427571177, 0.002124292775988579]]
# Prediction: [0], Truth: [0.0]
# Test Accuracy:  0.146
# Model Output: [[0.001184011809527874, 0.00373511272482574, 0.009218762628734112, 0.04528335481882095, 0.2798107862472534, 0.6607679724693298]]
# Prediction: [5], Truth: [5.0]
# Test Accuracy:  0.150
# Model Output: [[0.030833829194307327, 0.25990045070648193, 0.3932992219924927, 0.26564547419548035, 0.041145626455545425, 0.009175456129014492]]
# Prediction: [2], Truth: [3.0]
# Test Accuracy:  0.150
# Model Output: [[0.0030569557566195726, 0.022444937378168106, 0.10791701078414917, 0.49154841899871826, 0.2826439440250397, 0.09238877147436142]]
# Prediction: [3], Truth: [3.0]
# Test Accuracy:  0.155
# Model Output: [[0.00035174930235370994, 0.003907878417521715, 0.03468520566821098, 0.4328501224517822, 0.426165372133255, 0.10203967988491058]]
# Prediction: [3], Truth: [4.0]
# Test Accuracy:  0.155
# Model Output: [[0.8101622462272644, 0.15831607580184937, 0.02587660402059555, 0.0029294067062437534, 0.0009568898240104318, 0.0017588286427780986]]
# Prediction: [0], Truth: [2.0]
# Test Accuracy:  0.155
# Model Output: [[0.5060375332832336, 0.3908606469631195, 0.0840369239449501, 0.014574181288480759, 0.002564604626968503, 0.0019259718246757984]]
# Prediction: [0], Truth: [0.0]
# Test Accuracy:  0.159
# Model Output: [[0.2677682936191559, 0.2595216929912567, 0.2552652359008789, 0.15882766246795654, 0.04041719809174538, 0.018199937418103218]]
# Prediction: [0], Truth: [1.0]
# Test Accuracy:  0.159
# Model Output: [[0.0024985542986541986, 0.020491376519203186, 0.2657845914363861, 0.6099375486373901, 0.0902889147400856, 0.010999050922691822]]
# Prediction: [3], Truth: [3.0]
# Test Accuracy:  0.163
# Model Output: [[0.7808501124382019, 0.20051376521587372, 0.014460805803537369, 0.002752566011622548, 0.0005873669288121164, 0.0008354069432243705]]
# Prediction: [0], Truth: [0.0]
# Test Accuracy:  0.167
# Model Output: [[0.008007518015801907, 0.026473291218280792, 0.1308414340019226, 0.41324731707572937, 0.27849605679512024, 0.14293429255485535]]
# Prediction: [3], Truth: [2.0]
# Test Accuracy:  0.167
# Model Output: [[0.0030613259878009558, 0.03296883404254913, 0.27236783504486084, 0.47613731026649475, 0.18198180198669434, 0.03348280489444733]]
# Prediction: [3], Truth: [3.0]
# Test Accuracy:  0.172
# Model Output: [[0.006564855109900236, 0.05244430527091026, 0.2941393554210663, 0.4613392651081085, 0.1588626205921173, 0.02664961852133274]]
# Prediction: [3], Truth: [3.0]
# Test Accuracy:  0.176
# Model Output: [[0.011753789149224758, 0.052007947117090225, 0.19064949452877045, 0.3886859118938446, 0.22363367676734924, 0.13326920568943024]]
# Prediction: [3], Truth: [1.0]
# Test Accuracy:  0.176
# Model Output: [[0.011764829978346825, 0.07375376671552658, 0.31985247135162354, 0.4599597752094269, 0.11824169009923935, 0.01642744615674019]]
# Prediction: [3], Truth: [2.0]
# Test Accuracy:  0.176
# Model Output: [[0.002394085982814431, 0.011034651659429073, 0.05664261803030968, 0.25235384702682495, 0.4727975130081177, 0.20477737486362457]]
# Prediction: [4], Truth: [3.0]
# Test Accuracy:  0.176
# Model Output: [[0.0013844553614035249, 0.007402600720524788, 0.06202467903494835, 0.26353877782821655, 0.44878092408180237, 0.21686862409114838]]
# Prediction: [4], Truth: [0.0]
# Test Accuracy:  0.176
# Model Output: [[0.16777333617210388, 0.28250545263290405, 0.28328269720077515, 0.14815311133861542, 0.07544887065887451, 0.04283653199672699]]
# Prediction: [2], Truth: [0.0]
# Test Accuracy:  0.176
# Model Output: [[0.36441323161125183, 0.49351686239242554, 0.12816916406154633, 0.009355489164590836, 0.0027872270438820124, 0.0017580129206180573]]
# Prediction: [1], Truth: [0.0]
# Test Accuracy:  0.176
# Model Output: [[0.0014776159077882767, 0.007854398339986801, 0.033902447670698166, 0.1113658994436264, 0.41946181654930115, 0.42593780159950256]]
# Prediction: [5], Truth: [2.0]
# Test Accuracy:  0.176
# Model Output: [[0.3142232596874237, 0.48784568905830383, 0.15328024327754974, 0.03705168142914772, 0.005198339466005564, 0.0024008285254240036]]
# Prediction: [1], Truth: [0.0]
# Test Accuracy:  0.176
# Model Output: [[0.019255300983786583, 0.11687231808900833, 0.3835795223712921, 0.3879052698612213, 0.07972793281078339, 0.012659691274166107]]
# Prediction: [3], Truth: [3.0]
# Test Accuracy:  0.180
# Model Output: [[0.0005490707699209452, 0.0014898754889145494, 0.007864918559789658, 0.03157787024974823, 0.28603121638298035, 0.6724870204925537]]
# Prediction: [5], Truth: [4.0]
# Test Accuracy:  0.180
# Model Output: [[0.7271173000335693, 0.24669529497623444, 0.020391259342432022, 0.0036546397022902966, 0.0011299342149868608, 0.0010115883778780699]]
# Prediction: [0], Truth: [1.0]
# Test Accuracy:  0.180
# Model Output: [[0.002060132334008813, 0.010399702936410904, 0.036776844412088394, 0.24321265518665314, 0.4329744577407837, 0.27457618713378906]]
# Prediction: [4], Truth: [4.0]
# Test Accuracy:  0.185
# Model Output: [[0.02232898585498333, 0.11791450530290604, 0.3423061966896057, 0.46917951107025146, 0.043937623500823975, 0.004333203192800283]]
# Prediction: [3], Truth: [3.0]
# Test Accuracy:  0.189
# Model Output: [[0.54783034324646, 0.26866164803504944, 0.13645866513252258, 0.029649166390299797, 0.00867428258061409, 0.008725864812731743]]
# Prediction: [0], Truth: [1.0]
# Test Accuracy:  0.189
# Model Output: [[0.006042587570846081, 0.029871786013245583, 0.18018577992916107, 0.3185890018939972, 0.3210534155368805, 0.14425744116306305]]
# Prediction: [4], Truth: [2.0]
# Test Accuracy:  0.189
# Model Output: [[0.0013075261376798153, 0.016281716525554657, 0.20053672790527344, 0.5519030690193176, 0.21543893218040466, 0.014531990513205528]]
# Prediction: [3], Truth: [3.0]
# Test Accuracy:  0.193
# Model Output: [[0.10178839415311813, 0.23506900668144226, 0.33993250131607056, 0.22492952644824982, 0.062405090779066086, 0.03587545081973076]]
# Prediction: [2], Truth: [0.0]
# Test Accuracy:  0.193
# Model Output: [[0.053029317408800125, 0.2508082091808319, 0.48867666721343994, 0.1692448854446411, 0.03181948512792587, 0.006421409547328949]]
# Prediction: [2], Truth: [2.0]
# Test Accuracy:  0.197
# Model Output: [[0.024309780448675156, 0.08854179084300995, 0.2377849817276001, 0.36134418845176697, 0.22488990426063538, 0.0631294772028923]]
# Prediction: [3], Truth: [4.0]
# Test Accuracy:  0.197
# Model Output: [[0.0009213269804604352, 0.0038155470974743366, 0.032516542822122574, 0.19102883338928223, 0.3669455051422119, 0.4047723114490509]]
# Prediction: [5], Truth: [2.0]
# Test Accuracy:  0.197
# Model Output: [[0.007591193541884422, 0.029745623469352722, 0.19136527180671692, 0.37039390206336975, 0.2734702229499817, 0.1274338662624359]]
# Prediction: [3], Truth: [3.0]
# Test Accuracy:  0.202
# Model Output: [[0.13356369733810425, 0.34102779626846313, 0.287075400352478, 0.10079165548086166, 0.08160734176635742, 0.05593407154083252]]
# Prediction: [1], Truth: [5.0]
# Test Accuracy:  0.202
# Model Output: [[0.020920787006616592, 0.13860228657722473, 0.5345836877822876, 0.23612625896930695, 0.05957704782485962, 0.010189984925091267]]
# Prediction: [2], Truth: [1.0]
# Test Accuracy:  0.202
# Model Output: [[0.006195500958710909, 0.03864654153585434, 0.24624097347259521, 0.49528181552886963, 0.17482689023017883, 0.03880830854177475]]
# Prediction: [3], Truth: [1.0]
# Test Accuracy:  0.202
# Model Output: [[0.0009329206077381968, 0.004402856342494488, 0.02773546241223812, 0.09160571545362473, 0.47738558053970337, 0.39793750643730164]]
# Prediction: [4], Truth: [5.0]
# Test Accuracy:  0.202
# Model Output: [[0.029083117842674255, 0.16888684034347534, 0.46373018622398376, 0.26496219635009766, 0.06371103972196579, 0.009626714512705803]]
# Prediction: [2], Truth: [3.0]
# Test Accuracy:  0.202
# Model Output: [[0.058280106633901596, 0.20771798491477966, 0.3554105758666992, 0.2556416392326355, 0.0849311575293541, 0.03801853582262993]]
# Prediction: [2], Truth: [3.0]
# Test Accuracy:  0.202
# Model Output: [[0.015569169074296951, 0.14212821424007416, 0.5638578534126282, 0.2621280252933502, 0.013650044798851013, 0.002666713437065482]]
# Prediction: [2], Truth: [2.0]
# Test Accuracy:  0.206
# Model Output: [[0.0030670755077153444, 0.00763836782425642, 0.0463242307305336, 0.1064501479268074, 0.3206682503223419, 0.5158520340919495]]
# Prediction: [5], Truth: [5.0]
# Test Accuracy:  0.210
# Model Output: [[0.0035872457083314657, 0.013272393494844437, 0.06692703068256378, 0.23951666057109833, 0.5265036225318909, 0.15019312500953674]]
# Prediction: [4], Truth: [5.0]
# Test Accuracy:  0.210
# Model Output: [[0.7668009400367737, 0.2008436918258667, 0.02418242022395134, 0.005268830806016922, 0.0018408098258078098, 0.0010632544290274382]]
# Prediction: [0], Truth: [0.0]
# Test Accuracy:  0.215
# Model Output: [[0.060589008033275604, 0.2311617136001587, 0.5120818614959717, 0.16273213922977448, 0.028672505170106888, 0.004762768279761076]]
# Prediction: [2], Truth: [4.0]
# Test Accuracy:  0.215
# Model Output: [[0.004069282207638025, 0.012187995947897434, 0.05779796466231346, 0.2010784149169922, 0.3610444962978363, 0.3638218343257904]]
# Prediction: [5], Truth: [5.0]
# Test Accuracy:  0.219
# Model Output: [[0.0011470895260572433, 0.004756198264658451, 0.01724468544125557, 0.08079749345779419, 0.2497657984495163, 0.6462887525558472]]
# Prediction: [5], Truth: [5.0]
# Test Accuracy:  0.223
# Model Output: [[0.0010484002996236086, 0.001429096912033856, 0.012211566790938377, 0.0664122998714447, 0.26151975989341736, 0.6573789119720459]]
# Prediction: [5], Truth: [4.0]
# Test Accuracy:  0.223
# Model Output: [[0.40122973918914795, 0.3638159930706024, 0.1876513510942459, 0.03346826136112213, 0.009149931371212006, 0.004684666637331247]]
# Prediction: [0], Truth: [2.0]
# Test Accuracy:  0.223
# Model Output: [[0.015707606449723244, 0.08539890497922897, 0.3832874000072479, 0.4413470923900604, 0.06308472901582718, 0.011174311861395836]]
# Prediction: [3], Truth: [0.0]
# Test Accuracy:  0.223
# Model Output: [[0.004612430930137634, 0.02269754372537136, 0.10686369985342026, 0.3410988450050354, 0.37975674867630005, 0.14497078955173492]]
# Prediction: [4], Truth: [4.0]
# Test Accuracy:  0.227
# Model Output: [[0.0023188437335193157, 0.018896551802754402, 0.12652641534805298, 0.31836560368537903, 0.3877870738506317, 0.14610548317432404]]
# Prediction: [4], Truth: [3.0]
# Test Accuracy:  0.227
# Model Output: [[0.40958350896835327, 0.42976516485214233, 0.14168308675289154, 0.012165791355073452, 0.004453075584024191, 0.002349362475797534]]
# Prediction: [1], Truth: [0.0]
# Test Accuracy:  0.227
# Model Output: [[0.05913336202502251, 0.24359838664531708, 0.4274303615093231, 0.2317546308040619, 0.03172050043940544, 0.006362699903547764]]
# Prediction: [2], Truth: [2.0]
# Test Accuracy:  0.232
# Model Output: [[0.0019666883163154125, 0.013201327994465828, 0.11180794984102249, 0.4805290400981903, 0.30312344431877136, 0.08937151730060577]]
# Prediction: [3], Truth: [4.0]
# Test Accuracy:  0.232
# Model Output: [[0.0018090278608724475, 0.003670311998575926, 0.02815120480954647, 0.09010060131549835, 0.220315620303154, 0.6559532284736633]]
# Prediction: [5], Truth: [3.0]
# Test Accuracy:  0.232
# Model Output: [[0.8366255164146423, 0.14951132237911224, 0.008957373909652233, 0.0027659640181809664, 0.0008182687452062964, 0.001321575604379177]]
# Prediction: [0], Truth: [0.0]
# Test Accuracy:  0.236
# Model Output: [[0.04915643483400345, 0.28624582290649414, 0.37470462918281555, 0.25379616022109985, 0.030695272609591484, 0.005401689559221268]]
# Prediction: [2], Truth: [3.0]
# Test Accuracy:  0.236
# Model Output: [[0.5142423510551453, 0.36345019936561584, 0.08126064389944077, 0.017849253490567207, 0.01051732525229454, 0.012680220417678356]]
# Prediction: [0], Truth: [1.0]
# Test Accuracy:  0.236
# Model Output: [[0.0031545038800686598, 0.021317116916179657, 0.1470651775598526, 0.6625871658325195, 0.14157193899154663, 0.0243041031062603]]
# Prediction: [3], Truth: [3.0]
# Test Accuracy:  0.240
# Model Output: [[0.02430279180407524, 0.22608092427253723, 0.48281973600387573, 0.19208204746246338, 0.06011565029621124, 0.014598949812352657]]
# Prediction: [2], Truth: [2.0]
# Test Accuracy:  0.245
# Model Output: [[0.000707407423760742, 0.0013080062344670296, 0.0066254520788788795, 0.037416744977235794, 0.30217257142066956, 0.6517696976661682]]
# Prediction: [5], Truth: [5.0]
# Test Accuracy:  0.249
# Model Output: [[0.000666170206386596, 0.001244492712430656, 0.0025187968276441097, 0.011617856100201607, 0.15081776678562164, 0.8331349492073059]]
# Prediction: [5], Truth: [4.0]
# Test Accuracy:  0.249
# Model Output: [[0.17852038145065308, 0.4767090082168579, 0.29730600118637085, 0.038852475583553314, 0.0066030751913785934, 0.002009037183597684]]
# Prediction: [1], Truth: [3.0]
# Test Accuracy:  0.249
# Model Output: [[0.5951662659645081, 0.3396085798740387, 0.046553850173950195, 0.012954957783222198, 0.003341616364195943, 0.0023747447412461042]]
# Prediction: [0], Truth: [1.0]
# Test Accuracy:  0.249
# Model Output: [[0.013543154112994671, 0.08519862592220306, 0.21872903406620026, 0.374820351600647, 0.22284415364265442, 0.08486474305391312]]
# Prediction: [3], Truth: [0.0]
# Test Accuracy:  0.249
# Model Output: [[0.0007912133005447686, 0.005098973400890827, 0.046286195516586304, 0.2928841710090637, 0.40287768840789795, 0.25206172466278076]]
# Prediction: [4], Truth: [5.0]
# Test Accuracy:  0.249
# Model Output: [[0.0010694910306483507, 0.005410660058259964, 0.04881806671619415, 0.3476319909095764, 0.3868037462234497, 0.21026603877544403]]
# Prediction: [4], Truth: [4.0]
# Test Accuracy:  0.253
# Model Output: [[0.7032331228256226, 0.25605353713035583, 0.03139426186680794, 0.006101606879383326, 0.0013533359160646796, 0.0018641959177330136]]
# Prediction: [0], Truth: [2.0]
# Test Accuracy:  0.253
# Model Output: [[0.7936590313911438, 0.18971854448318481, 0.012613431550562382, 0.0023730346001684666, 0.0006157354800961912, 0.0010202731937170029]]
# Prediction: [0], Truth: [0.0]
# Test Accuracy:  0.258
# Model Output: [[0.16869249939918518, 0.44141146540641785, 0.30183979868888855, 0.06128881871700287, 0.018438348546624184, 0.008329177275300026]]
# Prediction: [1], Truth: [2.0]
# Test Accuracy:  0.258
# Model Output: [[0.0009088697261177003, 0.0019863774068653584, 0.005599680822342634, 0.02841883897781372, 0.19073030352592468, 0.7723559141159058]]
# Prediction: [5], Truth: [3.0]
# Test Accuracy:  0.258
# Model Output: [[0.0231722891330719, 0.19475369155406952, 0.3936349153518677, 0.31346648931503296, 0.06264255940914154, 0.012330005876719952]]
# Prediction: [2], Truth: [1.0]
# Test Accuracy:  0.258
# Model Output: [[0.0015406121965497732, 0.0013454083818942308, 0.0036967461928725243, 0.01700444146990776, 0.12357746064662933, 0.8528352975845337]]
# Prediction: [5], Truth: [5.0]
# Test Accuracy:  0.262
# Model Output: [[0.0004487911646720022, 0.0019389580702409148, 0.0053198207169771194, 0.026474956423044205, 0.3020918667316437, 0.6637256145477295]]
# Prediction: [5], Truth: [3.0]
# Test Accuracy:  0.262
# Model Output: [[0.6582419276237488, 0.28866836428642273, 0.039987776428461075, 0.008185341022908688, 0.0029050151351839304, 0.002011612057685852]]
# Prediction: [0], Truth: [0.0]
# Test Accuracy:  0.266
# Model Output: [[0.0024195038713514805, 0.0038195953238755465, 0.010465896688401699, 0.04678850248456001, 0.23098039627075195, 0.7055261731147766]]
# Prediction: [5], Truth: [4.0]
# Test Accuracy:  0.266
# Model Output: [[0.014223740436136723, 0.06456644833087921, 0.25954100489616394, 0.5542718768119812, 0.09222223609685898, 0.015174738131463528]]
# Prediction: [3], Truth: [2.0]
# Test Accuracy:  0.266
# Model Output: [[0.0014051184989511967, 0.00575155159458518, 0.03804249316453934, 0.12595051527023315, 0.5479735136032104, 0.28087687492370605]]
# Prediction: [4], Truth: [4.0]
# Test Accuracy:  0.270
# Model Output: [[0.10156149417161942, 0.3730827569961548, 0.4094768464565277, 0.0880061611533165, 0.023404642939567566, 0.004468081519007683]]
# Prediction: [2], Truth: [1.0]
# Test Accuracy:  0.270
# Model Output: [[0.3207893371582031, 0.5876742005348206, 0.07776659727096558, 0.011105199344456196, 0.001753058866597712, 0.0009115441935136914]]
# Prediction: [1], Truth: [1.0]
# Test Accuracy:  0.275
# Model Output: [[0.8517965078353882, 0.1297684758901596, 0.014682467095553875, 0.0015044596511870623, 0.0008292639395222068, 0.0014187701744958758]]
# Prediction: [0], Truth: [0.0]
# Test Accuracy:  0.279
# Model Output: [[0.20623530447483063, 0.26901817321777344, 0.2994091510772705, 0.1574837863445282, 0.04867711290717125, 0.01917644590139389]]
# Prediction: [2], Truth: [0.0]
# Test Accuracy:  0.279
# Model Output: [[0.0016047056997194886, 0.004153716843575239, 0.00799617450684309, 0.02669629640877247, 0.25641006231307983, 0.703139066696167]]
# Prediction: [5], Truth: [5.0]
# Test Accuracy:  0.283
# Model Output: [[0.0019495547749102116, 0.0021971294190734625, 0.00835342425853014, 0.025934718549251556, 0.11552377045154572, 0.8460414409637451]]
# Prediction: [5], Truth: [5.0]
# Test Accuracy:  0.288
# Model Output: [[0.1825011968612671, 0.5499987602233887, 0.22489531338214874, 0.0357859767973423, 0.005341482348740101, 0.001477331155911088]]
# Prediction: [1], Truth: [3.0]
# Test Accuracy:  0.288
# Model Output: [[0.8639886975288391, 0.11990564316511154, 0.01254769042134285, 0.0016427962109446526, 0.0008720337064005435, 0.00104305031709373]]
# Prediction: [0], Truth: [0.0]
# Test Accuracy:  0.292
# Model Output: [[0.014210628345608711, 0.0943131372332573, 0.29996272921562195, 0.33325982093811035, 0.18623346090316772, 0.07202025502920151]]
# Prediction: [3], Truth: [3.0]
# Test Accuracy:  0.296
# Model Output: [[0.0014334347797557712, 0.005925789475440979, 0.06860816478729248, 0.3096238076686859, 0.46158596873283386, 0.15282291173934937]]
# Prediction: [4], Truth: [4.0]
# Test Accuracy:  0.300
# Model Output: [[0.2203398495912552, 0.4717065095901489, 0.23021915555000305, 0.06585919111967087, 0.009035840630531311, 0.0028394274413585663]]
# Prediction: [1], Truth: [3.0]
# Test Accuracy:  0.300
# Model Output: [[0.3807779550552368, 0.41251230239868164, 0.1264205425977707, 0.05020555853843689, 0.01781146228313446, 0.01227217074483633]]
# Prediction: [1], Truth: [0.0]
# Test Accuracy:  0.300
# Model Output: [[0.16557401418685913, 0.35880550742149353, 0.24838201701641083, 0.15156550705432892, 0.043651215732097626, 0.03202180936932564]]
# Prediction: [1], Truth: [2.0]
# Test Accuracy:  0.300
# Model Output: [[0.0062550888396799564, 0.01855926588177681, 0.14596113562583923, 0.47475767135620117, 0.24524705111980438, 0.10921985656023026]]
# Prediction: [3], Truth: [5.0]
# Test Accuracy:  0.300
# Model Output: [[0.1559581160545349, 0.3395839035511017, 0.2381654530763626, 0.11021804809570312, 0.06417869031429291, 0.09189586341381073]]
# Prediction: [1], Truth: [0.0]
# Test Accuracy:  0.300
# Model Output: [[0.7940185070037842, 0.16554483771324158, 0.03564080595970154, 0.0026218246202915907, 0.0011059388052672148, 0.0010682387510314584]]
# Prediction: [0], Truth: [2.0]
# Test Accuracy:  0.300
# Model Output: [[0.008334755897521973, 0.05752178654074669, 0.257412314414978, 0.4859549105167389, 0.14463567733764648, 0.046140626072883606]]
# Prediction: [3], Truth: [3.0]
# Test Accuracy:  0.305
# Model Output: [[0.0013639535754919052, 0.017704354599118233, 0.2116553783416748, 0.4260435104370117, 0.2709285616874695, 0.07230429351329803]]
# Prediction: [3], Truth: [2.0]
# Test Accuracy:  0.305
# Model Output: [[0.01926511898636818, 0.09067657589912415, 0.3227357566356659, 0.4013312757015228, 0.12983782589435577, 0.03615342080593109]]
# Prediction: [3], Truth: [1.0]
# Test Accuracy:  0.305
# Model Output: [[0.022711150348186493, 0.12920363247394562, 0.34542590379714966, 0.3303814232349396, 0.1421688199043274, 0.030109059065580368]]
# Prediction: [2], Truth: [4.0]
# Test Accuracy:  0.305
# Model Output: [[0.0029143928550183773, 0.022604316473007202, 0.08904922753572464, 0.5633014440536499, 0.26754018664360046, 0.05459046736359596]]
# Prediction: [3], Truth: [4.0]
# Test Accuracy:  0.305
# Model Output: [[0.001418856205418706, 0.002799228997901082, 0.00548787834122777, 0.034154877066612244, 0.2363680601119995, 0.7197710871696472]]
# Prediction: [5], Truth: [4.0]
# Test Accuracy:  0.305
# Model Output: [[0.20710942149162292, 0.49592021107673645, 0.20746532082557678, 0.04867373779416084, 0.025090260431170464, 0.015741100534796715]]
# Prediction: [1], Truth: [0.0]
# Test Accuracy:  0.305
# Model Output: [[0.0008234985289163888, 0.0037823827005922794, 0.018134653568267822, 0.07465249300003052, 0.336710125207901, 0.5658968091011047]]
# Prediction: [5], Truth: [5.0]
# Test Accuracy:  0.309
# Model Output: [[0.0014315953012555838, 0.0015445429598912597, 0.00493230763822794, 0.01943311281502247, 0.22628459334373474, 0.7463738322257996]]
# Prediction: [5], Truth: [5.0]
# Test Accuracy:  0.313
# Model Output: [[0.7379061579704285, 0.240402489900589, 0.017070643603801727, 0.0028209546580910683, 0.0007141768001019955, 0.0010856071021407843]]
# Prediction: [0], Truth: [1.0]
# Test Accuracy:  0.313
# Model Output: [[0.006940643768757582, 0.024270018562674522, 0.21313616633415222, 0.5206447243690491, 0.1793152391910553, 0.055693212896585464]]
# Prediction: [3], Truth: [4.0]
# Test Accuracy:  0.313
# Model Output: [[0.030884461477398872, 0.09315106272697449, 0.2352534681558609, 0.3122977912425995, 0.21294322609901428, 0.11546993255615234]]
# Prediction: [3], Truth: [3.0]
# Test Accuracy:  0.318
# Model Output: [[0.3539794087409973, 0.5496596693992615, 0.08489398658275604, 0.008564271964132786, 0.001593303750269115, 0.0013093941379338503]]
# Prediction: [1], Truth: [3.0]
# Test Accuracy:  0.318
# Model Output: [[0.056658852845430374, 0.3254088759422302, 0.4049876034259796, 0.16605396568775177, 0.038786403834819794, 0.008104396052658558]]
# Prediction: [2], Truth: [1.0]
# Test Accuracy:  0.318
# Model Output: [[0.4997597932815552, 0.4288369119167328, 0.06469345092773438, 0.004314932972192764, 0.0014117552200332284, 0.000983106903731823]]
# Prediction: [0], Truth: [2.0]
# Test Accuracy:  0.318
# Model Output: [[0.24400651454925537, 0.26642224192619324, 0.11878303438425064, 0.0649043619632721, 0.08316893875598907, 0.2227148711681366]]
# Prediction: [1], Truth: [1.0]
# Test Accuracy:  0.322
# Model Output: [[0.2582804560661316, 0.4581778347492218, 0.2281845062971115, 0.046325355768203735, 0.006422297563403845, 0.0026094643399119377]]
# Prediction: [1], Truth: [0.0]
# Test Accuracy:  0.322
# Model Output: [[0.054558511823415756, 0.17139017581939697, 0.26343801617622375, 0.3717457354068756, 0.11165733635425568, 0.02721024490892887]]
# Prediction: [3], Truth: [2.0]
# Test Accuracy:  0.322
# Model Output: [[0.000683058868162334, 0.0010602978290989995, 0.006589927244931459, 0.020116370171308517, 0.3127821087837219, 0.6587682366371155]]
# Prediction: [5], Truth: [5.0]
# Test Accuracy:  0.326
# Model Output: [[0.3559478223323822, 0.4472405016422272, 0.1516028493642807, 0.03167060762643814, 0.00956759788095951, 0.003970584366470575]]
# Prediction: [1], Truth: [0.0]
# Test Accuracy:  0.326
# Model Output: [[0.001059682690538466, 0.00287828641012311, 0.020919200032949448, 0.14759190380573273, 0.2954115867614746, 0.5321393013000488]]
# Prediction: [5], Truth: [5.0]
# Test Accuracy:  0.330
# Model Output: [[0.5661752223968506, 0.4086047410964966, 0.020068055018782616, 0.002506143180653453, 0.0010677122045308352, 0.0015780525282025337]]
# Prediction: [0], Truth: [0.0]
# Test Accuracy:  0.335
# Model Output: [[0.6115236878395081, 0.345344603061676, 0.02963990718126297, 0.0085025979205966, 0.002929289359599352, 0.0020598494447767735]]
# Prediction: [0], Truth: [0.0]
# Test Accuracy:  0.339
# Model Output: [[0.0006420298013836145, 0.001901341020129621, 0.014052057638764381, 0.17694008350372314, 0.3481667637825012, 0.4582976698875427]]
# Prediction: [5], Truth: [4.0]
# Test Accuracy:  0.339
# Model Output: [[0.0009516842546872795, 0.0013333186507225037, 0.004692576825618744, 0.017163781449198723, 0.23005150258541107, 0.7458071708679199]]
# Prediction: [5], Truth: [5.0]
# Test Accuracy:  0.343
# Model Output: [[0.5580825805664062, 0.4109395146369934, 0.02597665600478649, 0.0034498681779950857, 0.0009318077936768532, 0.0006196058820933104]]
# Prediction: [0], Truth: [2.0]
# Test Accuracy:  0.343
# Model Output: [[0.012129687704145908, 0.0450359582901001, 0.20406919717788696, 0.4194523096084595, 0.21202929317951202, 0.10728364437818527]]
# Prediction: [3], Truth: [1.0]
# Test Accuracy:  0.343
# Model Output: [[0.01508084125816822, 0.05768044665455818, 0.20641817152500153, 0.43798476457595825, 0.20375800132751465, 0.07907776534557343]]
# Prediction: [3], Truth: [2.0]
# Test Accuracy:  0.343
# Model Output: [[0.0014664302580058575, 0.010412415489554405, 0.04840809106826782, 0.3300838768482208, 0.4390697479248047, 0.17055943608283997]]
# Prediction: [4], Truth: [5.0]
# Test Accuracy:  0.343
# Model Output: [[0.036040276288986206, 0.1267685890197754, 0.2427625209093094, 0.37365269660949707, 0.15602770447731018, 0.06474822759628296]]
# Prediction: [3], Truth: [1.0]
# Test Accuracy:  0.343
# Model Output: [[0.0013547460548579693, 0.0037505612708628178, 0.013561313040554523, 0.09344176203012466, 0.30943822860717773, 0.5784533619880676]]
# Prediction: [5], Truth: [4.0]
# Test Accuracy:  0.343
# Model Output: [[0.0023434292525053024, 0.025315893813967705, 0.1593627780675888, 0.4360191822052002, 0.3105505704879761, 0.06640812009572983]]
# Prediction: [3], Truth: [4.0]
# Test Accuracy:  0.343
# Model Output: [[0.028735682368278503, 0.09258776903152466, 0.26735419034957886, 0.3806520402431488, 0.15543539822101593, 0.07523492723703384]]
# Prediction: [3], Truth: [1.0]
# Test Accuracy:  0.343
# Model Output: [[0.0012099648592993617, 0.009025165811181068, 0.049037810415029526, 0.25003427267074585, 0.5066981315612793, 0.18399472534656525]]
# Prediction: [4], Truth: [4.0]
# Test Accuracy:  0.348
# Model Output: [[0.8847336173057556, 0.09555245190858841, 0.01520670298486948, 0.003137586871162057, 0.00041030795546248555, 0.0009594173170626163]]
# Prediction: [0], Truth: [0.0]
# Test Accuracy:  0.352
# Model Output: [[0.7968142032623291, 0.1865096241235733, 0.013284017331898212, 0.001907497993670404, 0.0006992245325818658, 0.0007854012656025589]]
# Prediction: [0], Truth: [0.0]
# Test Accuracy:  0.356
# Model Output: [[0.7277790904045105, 0.23752067983150482, 0.024721704423427582, 0.006271796301007271, 0.001973561942577362, 0.001733149983920157]]
# Prediction: [0], Truth: [1.0]
# Test Accuracy:  0.356
# Model Output: [[0.1256437450647354, 0.17503079771995544, 0.152145653963089, 0.15606790781021118, 0.14581282436847687, 0.2452990710735321]]
# Prediction: [5], Truth: [3.0]
# Test Accuracy:  0.356
# Model Output: [[0.6657562255859375, 0.29924672842025757, 0.02443178929388523, 0.005729125812649727, 0.002125983824953437, 0.0027101330924779177]]
# Prediction: [0], Truth: [2.0]
# Test Accuracy:  0.356
# Model Output: [[0.0037450448144227266, 0.01655777171254158, 0.0716068372130394, 0.29715317487716675, 0.40796321630477905, 0.2029738873243332]]
# Prediction: [4], Truth: [1.0]
# Test Accuracy:  0.356
# Model Output: [[0.008760756812989712, 0.057804182171821594, 0.2631637454032898, 0.49643582105636597, 0.13334718346595764, 0.04048817977309227]]
# Prediction: [3], Truth: [4.0]
# Test Accuracy:  0.356
# Model Output: [[0.01279679499566555, 0.08703877776861191, 0.39541712403297424, 0.4157271981239319, 0.07394977658987045, 0.015070388093590736]]
# Prediction: [3], Truth: [1.0]
# Test Accuracy:  0.356
# Model Output: [[0.053805891424417496, 0.24047201871871948, 0.3915988504886627, 0.2156805545091629, 0.07123558968305588, 0.0272071436047554]]
# Prediction: [2], Truth: [0.0]
# Test Accuracy:  0.356
# Model Output: [[0.0376674123108387, 0.20285794138908386, 0.5350064039230347, 0.18777593970298767, 0.032179754227399826, 0.004512604791671038]]
# Prediction: [2], Truth: [1.0]
# Test Accuracy:  0.356
# Model Output: [[0.6536456942558289, 0.3146100342273712, 0.02763322927057743, 0.002156556351110339, 0.0012658712221309543, 0.0006885767797939479]]
# Prediction: [0], Truth: [1.0]
# Test Accuracy:  0.356
# Model Output: [[0.01118164137005806, 0.035605136305093765, 0.1326880007982254, 0.4492109417915344, 0.26688113808631897, 0.10443321615457535]]
# Prediction: [3], Truth: [2.0]
# Test Accuracy:  0.356
# Model Output: [[0.549490213394165, 0.370575875043869, 0.059599392116069794, 0.011675529181957245, 0.004117811098694801, 0.004541170783340931]]
# Prediction: [0], Truth: [0.0]
# Test Accuracy:  0.361
# Model Output: [[0.0010366926435381174, 0.002734751207754016, 0.008912554010748863, 0.04241413623094559, 0.2346554547548294, 0.7102463841438293]]
# Prediction: [5], Truth: [4.0]
# Test Accuracy:  0.361
# Model Output: [[0.05091814324259758, 0.17938320338726044, 0.5377803444862366, 0.183710515499115, 0.03852188214659691, 0.009685955941677094]]
# Prediction: [2], Truth: [1.0]
# Test Accuracy:  0.361
# Model Output: [[0.005273938179016113, 0.03550790995359421, 0.17136149108409882, 0.39763161540031433, 0.27423468232154846, 0.11599032580852509]]
# Prediction: [3], Truth: [5.0]
# Test Accuracy:  0.361
# Model Output: [[0.00829293578863144, 0.0895044356584549, 0.5369770526885986, 0.29703640937805176, 0.05447884276509285, 0.013710403814911842]]
# Prediction: [2], Truth: [0.0]
# Test Accuracy:  0.361
# Model Output: [[0.006242666859179735, 0.04571126028895378, 0.3029579520225525, 0.4516623914241791, 0.16497182846069336, 0.028453854843974113]]
# Prediction: [3], Truth: [4.0]
# Test Accuracy:  0.361
# Model Output: [[0.0016002272022888064, 0.006368855945765972, 0.043822985142469406, 0.3279287815093994, 0.3637203574180603, 0.25655877590179443]]
# Prediction: [4], Truth: [5.0]
# Test Accuracy:  0.361
# Model Output: [[0.002418582094833255, 0.013382320292294025, 0.076225645840168, 0.24231866002082825, 0.40116098523139954, 0.264493852853775]]
# Prediction: [4], Truth: [2.0]
# Test Accuracy:  0.361
# Model Output: [[0.002529416000470519, 0.01710817776620388, 0.16384385526180267, 0.4537225663661957, 0.30450138449668884, 0.05829461291432381]]
# Prediction: [3], Truth: [4.0]
# Test Accuracy:  0.361
# Model Output: [[0.060152340680360794, 0.14889934659004211, 0.19031567871570587, 0.20385244488716125, 0.22685594856739044, 0.16992418467998505]]
# Prediction: [4], Truth: [5.0]
# Test Accuracy:  0.361
# Model Output: [[0.0904175415635109, 0.34715136885643005, 0.4258915185928345, 0.11059467494487762, 0.019459934905171394, 0.00648504076525569]]
# Prediction: [2], Truth: [0.0]
# Test Accuracy:  0.361
# Model Output: [[0.5811876654624939, 0.3757407069206238, 0.0383756160736084, 0.0025407837238162756, 0.0010580674279481173, 0.0010971412993967533]]
# Prediction: [0], Truth: [1.0]
# Test Accuracy:  0.361
# Model Output: [[0.6242020726203918, 0.3498343229293823, 0.01843472570180893, 0.004047418478876352, 0.0012528373626992106, 0.0022286069579422474]]
# Prediction: [0], Truth: [0.0]
# Test Accuracy:  0.365
# Model Output: [[0.001132026663981378, 0.008003742434084415, 0.05716739594936371, 0.4066496789455414, 0.3154294788837433, 0.21161770820617676]]
# Prediction: [3], Truth: [4.0]
# Test Accuracy:  0.365
# Model Output: [[0.01378127746284008, 0.0655517429113388, 0.3025934100151062, 0.47754359245300293, 0.11595457792282104, 0.024575434625148773]]
# Prediction: [3], Truth: [3.0]
# Test Accuracy:  0.369
# Model Output: [[0.01115067396312952, 0.08103152364492416, 0.36388468742370605, 0.4212672710418701, 0.10598510503768921, 0.016680745407938957]]
# Prediction: [3], Truth: [4.0]
# Test Accuracy:  0.369
# Model Output: [[0.00109651789534837, 0.003055875888094306, 0.0173333752900362, 0.11153683811426163, 0.44444745779037476, 0.4225298762321472]]
# Prediction: [4], Truth: [5.0]
# Test Accuracy:  0.369
# Model Output: [[0.0056758360005915165, 0.059777893126010895, 0.31482598185539246, 0.4857344925403595, 0.11337356269359589, 0.020612318068742752]]
# Prediction: [3], Truth: [3.0]
# Test Accuracy:  0.373
# Model Output: [[0.01919555850327015, 0.08927121758460999, 0.33446407318115234, 0.4098014235496521, 0.12397874891757965, 0.023288965225219727]]
# Prediction: [3], Truth: [0.0]
# Test Accuracy:  0.373
# Model Output: [[0.18073011934757233, 0.3984612226486206, 0.27882248163223267, 0.1088363379240036, 0.02447749301791191, 0.00867227278649807]]
# Prediction: [1], Truth: [0.0]
# Test Accuracy:  0.373
